# %% [markdown]
# # pyrmaid pattern make above in while loop
# #  if condition:
# # elif another_condition:
# #  pass
# # else:
# # ==!= > < >= <= and or not

# %%
marks = 85
if marks >= 90:
   grade = 'A'
elif marks >= 80:
    grade = 'B'
elif marks >= 70:
    grade = 'c'
elif marks >= 60:
    grade = 'D'
else:
    grade = 'F'

print(f"grade of the student:  {grade}")
# Out:
# grade of the student:  B

# %%
marks = int(input("enter marks:"))
print(marks)

# this is an assignment
